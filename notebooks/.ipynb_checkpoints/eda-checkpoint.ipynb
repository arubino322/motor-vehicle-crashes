# %%
import json
import os
import shutil
from datetime import date, timedelta

import pandas as pd
import requests
from google.cloud import storage

# %% [markdown]
# ### API documentation
# https://dev.socrata.com/docs/filtering

# %%
"""Download the latest additions and updates to the NYC Open Data portal."""
from __future__ import annotations

from datetime import datetime
from pathlib import Path

import click
import pytz
import requests
from retry import retry
from rich import print

from . import utils


@click.command()
@click.option(
    "--verbose",
    "-v",
    is_flag=True,
    default=False,
    help="Print verbose output.",
)
def download(verbose: bool) -> None:
    """Download the latest additions and updates to the NYC Open Data portal."""
    this_dir = Path(__file__).parent.absolute()
    data_dir = this_dir.parent / "data" / "raw"

    # Get the current time
    tz = pytz.timezone("America/New_York")
    now = datetime.now(tz=tz)

    # Get the data
    data = get_url(verbose=verbose)

    # Write them out
    if verbose:
        print(f"Writing to [bold]{data_dir}[/bold]")
    utils.write_json(data["results"], data_dir / f"{now.isoformat()}.json")
    utils.write_json(data["results"], data_dir / "latest.json")


@retry()
def get_url(
    domains: str | list[str] = "data.cityofnewyork.us",
    search_context: str = "data.cityofnewyork.us",
    limit: int = 10000,
    order: str = "updatedAt",
    verbose: bool = True,
) -> dict:
    """Connect with the Socrata API."""
    url = "http://api.us.socrata.com/api/catalog/v1"
    params = {
        "domains": domains,
        "search_context": search_context,
        "limit": limit,
        "order": order,
    }
    if verbose:
        print(f"Downloading [bold]{url}[/bold]")
    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json()
    if verbose:
        print(f"Found [bold]{len(data['results'])}[/bold] results.")
    return data


if __name__ == "__main__":
    download()

# %%
# pedestrian crash API endpoint: https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Person/f55k-p6yu/about_data
url = "https://data.cityofnewyork.us/resource/f55k-p6yu.json?$order=crash_date DESC&$limit=25"

# %%
api_key, secret_key = os.environ['NYCT_API_KEY'], os.environ['NYCT_SECRET_KEY']
r = requests.get(url, auth=(api_key, secret_key))
r.status_code
# Out:
# 200

# %%
d = r.json()
print(len(d))
d
# Out:
# 25
# [{'unique_id': '12979421',
#   'collision_id': '4725105',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '17:10',
#   'person_id': 'a85b0abc-51ad-428a-afe8-113598e37c48',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20651225',
#   'ped_role': 'Registrant'},
#  {'unique_id': '12976605',
#   'collision_id': '4724633',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '16:57',
#   'person_id': '645b9400-9e3c-4182-ab64-513345a2456d',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20649755',
#   'person_age': '20',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Unknown',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12978662',
#   'collision_id': '4724811',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '10:16',
#   'person_id': 'fc31ecac-61df-4563-bf76-70922ade7082',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650821',
#   'person_age': '21',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12977675',
#   'collision_id': '4724535',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '11:11',
#   'person_id': '1925b9c1-2de2-4362-969a-39e4e9e1447d',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650268',
#   'person_age': '71',
#   'ped_role': 'Registrant',
#   'person_sex': 'M'},
#  {'unique_id': '12977101',
#   'collision_id': '4724651',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '18:55',
#   'person_id': '214ebb56-6059-4c39-a0ca-ff26121bd937',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650000',
#   'person_age': '38',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'None',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'F'},
#  {'unique_id': '12977205',
#   'collision_id': '4724607',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '13:30',
#   'person_id': 'df43c678-02d4-447d-b742-3d426f6410d6',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650049',
#   'person_age': '70',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12977219',
#   'collision_id': '4724502',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '6:20',
#   'person_id': 'd2fac427-6ef1-4893-a798-833a26116047',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650054',
#   'person_age': '9',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Middle rear seat, or passenger lying across a seat',
#   'safety_equipment': 'Lap Belt',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Passenger',
#   'person_sex': 'M'},
#  {'unique_id': '12978640',
#   'collision_id': '4724626',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '17:15',
#   'person_id': 'aec8f6dc-34f8-44a3-af4a-7fe91030fc12',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650807',
#   'person_age': '7',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Left rear passenger, or rear passenger on a bicycle, motorcycle, snowmobile',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Passenger',
#   'person_sex': 'M'},
#  {'unique_id': '12979970',
#   'collision_id': '4725127',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '8:56',
#   'person_id': '3f6d4e79-f9ca-401a-a3de-37c7f4b3666d',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20651513',
#   'person_age': '81',
#   'ped_role': 'Registrant',
#   'person_sex': 'F'},
#  {'unique_id': '12977593',
#   'collision_id': '4724642',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '16:30',
#   'person_id': '72718275-ebfe-4c01-a82f-5cf7ac5add2b',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650225',
#   'person_age': '67',
#   'ped_role': 'Registrant',
#   'person_sex': 'F'},
#  {'unique_id': '12977065',
#   'collision_id': '4724648',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '10:10',
#   'person_id': '4949fe87-dc8f-45fb-87eb-934ed0eacfdf',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20649989',
#   'person_age': '7',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Any person in the rear of a station wagon, pick-up truck, all passengers on a bus, etc',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Passenger',
#   'person_sex': 'M'},
#  {'unique_id': '12976543',
#   'collision_id': '4724388',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '0:00',
#   'person_id': '97386294-330e-46e7-ae97-999f062a882b',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20649718',
#   'ped_role': 'Registrant',
#   'person_sex': 'M'},
#  {'unique_id': '12977620',
#   'collision_id': '4724666',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '17:53',
#   'person_id': '68d8a823-739d-4fb6-9068-1315f48b333b',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650237',
#   'person_age': '36',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12978706',
#   'collision_id': '4724747',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '11:30',
#   'person_id': 'f0249fc2-af02-4a8f-8f63-7222450e9617',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650846',
#   'person_age': '57',
#   'ped_role': 'Registrant',
#   'person_sex': 'F'},
#  {'unique_id': '12979419',
#   'collision_id': '4725105',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '17:10',
#   'person_id': 'db7c2aef-2d44-4f7c-8916-48f1fd45416d',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20651226',
#   'person_age': '20',
#   'ped_role': 'Registrant',
#   'person_sex': 'M'},
#  {'unique_id': '12978238',
#   'collision_id': '4724806',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '11:30',
#   'person_id': '4e5e48e8-d1b2-4f29-9a10-e16fc6c26c93',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650584',
#   'person_age': '64',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12978734',
#   'collision_id': '4724742',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '16:30',
#   'person_id': '4b405fae-c8ba-4a01-940c-ad6b55ba2e17',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650860',
#   'person_age': '31',
#   'ped_role': 'Registrant',
#   'person_sex': 'M'},
#  {'unique_id': '12977529',
#   'collision_id': '4724670',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '5:45',
#   'person_id': '21c71205-4059-4d29-b7ba-c2006f3170da',
#   'person_type': 'Occupant',
#   'person_injury': 'Injured',
#   'vehicle_id': '20650181',
#   'person_age': '24',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Conscious',
#   'bodily_injury': 'Head',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'None Visible',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12977972',
#   'collision_id': '4724931',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '10:00',
#   'person_id': 'c3c909e9-c769-4977-b504-d014f8eeab8e',
#   'person_type': 'Occupant',
#   'person_injury': 'Injured',
#   'vehicle_id': '20650433',
#   'person_age': '49',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Conscious',
#   'bodily_injury': 'Neck',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Crush Injuries',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12976946',
#   'collision_id': '4724618',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '13:33',
#   'person_id': '6b8d3baa-b7f0-461f-a4f5-8478b934be06',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20649924',
#   'person_age': '30',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Unknown',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12978121',
#   'collision_id': '4724846',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '19:10',
#   'person_id': 'fa47d0a9-b4eb-4d39-9a2a-86cd9e385f3d',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650509',
#   'person_age': '37',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt & Harness',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12978179',
#   'collision_id': '4724865',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '8:50',
#   'person_id': '2130b230-2356-4c11-8aa0-e2ac42ca34ad',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650545',
#   'person_age': '60',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Unknown',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'},
#  {'unique_id': '12978919',
#   'collision_id': '4724731',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '11:10',
#   'person_id': '9cf15b52-b934-4e1a-a8ab-a89fadd783a3',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650965',
#   'person_age': '65',
#   'ped_role': 'Registrant',
#   'person_sex': 'M'},
#  {'unique_id': '12977456',
#   'collision_id': '4724672',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '21:25',
#   'person_id': '957eefec-d83d-4b54-8e09-7dc9746dde81',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'ped_role': 'Witness'},
#  {'unique_id': '12978918',
#   'collision_id': '4724731',
#   'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '11:10',
#   'person_id': 'cdb183db-570c-460a-be65-f1675ed41f94',
#   'person_type': 'Occupant',
#   'person_injury': 'Unspecified',
#   'vehicle_id': '20650964',
#   'person_age': '40',
#   'ejection': 'Not Ejected',
#   'emotional_status': 'Does Not Apply',
#   'bodily_injury': 'Does Not Apply',
#   'position_in_vehicle': 'Driver',
#   'safety_equipment': 'Lap Belt',
#   'complaint': 'Does Not Apply',
#   'ped_role': 'Driver',
#   'person_sex': 'M'}]

# %%
# motor vehicle collision API endpoint: https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95/about_data
c_url = "https://data.cityofnewyork.us/resource/h9gi-nx95.json?$order=crash_date DESC&$limit=25"

# %%
r2 = requests.get(c_url, auth=(api_key, secret_key))
r2.status_code
# Out:
# 200

# %%
d2 = r2.json()
print(len(d2))
d2
# Out:
# 25
# [{'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '9:50',
#   'borough': 'BROOKLYN',
#   'zip_code': '11211',
#   'latitude': '40.713017',
#   'longitude': '-73.93632',
#   'location': {'latitude': '40.713017',
#    'longitude': '-73.93632',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '951       GRAND STREET',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '2',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Driver Inattention/Distraction',
#   'collision_id': '4724746',
#   'vehicle_type_code1': 'Box Truck',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '22:30',
#   'latitude': '40.584557',
#   'longitude': '-73.950874',
#   'location': {'latitude': '40.584557',
#    'longitude': '-73.950874',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BELT PARKWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724713',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '7:50',
#   'latitude': '40.824417',
#   'longitude': '-73.87357',
#   'location': {'latitude': '40.824417',
#    'longitude': '-73.87357',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BRUCKNER BOULEVARD',
#   'off_street_name': 'MORRISON AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing or Lane Usage Improper',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724841',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '15:40',
#   'latitude': '40.7773',
#   'longitude': '-73.98259',
#   'location': {'latitude': '40.7773',
#    'longitude': '-73.98259',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'AMSTERDAM AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unsafe Lane Changing',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4725181',
#   'vehicle_type_code1': 'Bus',
#   'vehicle_type_code2': 'Box Truck'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '20:45',
#   'borough': 'BRONX',
#   'zip_code': '10468',
#   'latitude': '40.869408',
#   'longitude': '-73.90213',
#   'location': {'latitude': '40.869408',
#    'longitude': '-73.90213',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAMES PLACE',
#   'off_street_name': 'WEBB AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'collision_id': '4724803',
#   'vehicle_type_code1': 'Pick-up Truck'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '0:36',
#   'latitude': '40.761272',
#   'longitude': '-73.95571',
#   'location': {'latitude': '40.761272',
#    'longitude': '-73.95571',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'FDR DRIVE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724722',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '19:28',
#   'borough': 'BROOKLYN',
#   'zip_code': '11219',
#   'latitude': '40.6406',
#   'longitude': '-73.99434',
#   'location': {'latitude': '40.6406',
#    'longitude': '-73.99434',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'NEW UTRECHT AVENUE',
#   'off_street_name': 'FORT HAMILTON PARKWAY',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Alcohol Involvement',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724663',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '16:10',
#   'borough': 'QUEENS',
#   'zip_code': '11420',
#   'latitude': '40.677303',
#   'longitude': '-73.804565',
#   'location': {'latitude': '40.677303',
#    'longitude': '-73.804565',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'FOCH BOULEVARD',
#   'off_street_name': '135 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Traffic Control Disregarded',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724671',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '17:10',
#   'latitude': '40.724174',
#   'longitude': '-73.937355',
#   'location': {'latitude': '40.724174',
#    'longitude': '-73.937355',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BROOKLYN QUEENS EXPRESSWAY',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4725105',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Motorcycle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '22:30',
#   'latitude': '40.703712',
#   'longitude': '-73.90677',
#   'location': {'latitude': '40.703712',
#    'longitude': '-73.90677',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'ONDERDONK AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4725006',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '14:22',
#   'borough': 'QUEENS',
#   'zip_code': '11422',
#   'latitude': '40.664085',
#   'longitude': '-73.731865',
#   'location': {'latitude': '40.664085',
#    'longitude': '-73.731865',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '248 STREET',
#   'off_street_name': '139 AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Traffic Control Disregarded',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724632',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '20:50',
#   'borough': 'MANHATTAN',
#   'zip_code': '10036',
#   'latitude': '40.760353',
#   'longitude': '-73.99124',
#   'location': {'latitude': '40.760353',
#    'longitude': '-73.99124',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '9 AVENUE',
#   'off_street_name': 'WEST 45 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unsafe Lane Changing',
#   'contributing_factor_vehicle_2': 'Unsafe Lane Changing',
#   'collision_id': '4724861',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '8:15',
#   'borough': 'QUEENS',
#   'zip_code': '11378',
#   'latitude': '40.72863',
#   'longitude': '-73.90124',
#   'location': {'latitude': '40.72863',
#    'longitude': '-73.90124',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '64 STREET',
#   'off_street_name': '53 DRIVE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724700',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '13:50',
#   'borough': 'MANHATTAN',
#   'zip_code': '10035',
#   'latitude': '40.802086',
#   'longitude': '-73.93701',
#   'location': {'latitude': '40.802086',
#    'longitude': '-73.93701',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '2252      3 AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724890',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '16:14',
#   'borough': 'BRONX',
#   'zip_code': '10473',
#   'latitude': '40.820847',
#   'longitude': '-73.84846',
#   'location': {'latitude': '40.820847',
#    'longitude': '-73.84846',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '635       CASTLE HILL AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'collision_id': '4724848',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '9:20',
#   'borough': 'BROOKLYN',
#   'zip_code': '11228',
#   'latitude': '40.604107',
#   'longitude': '-74.01824',
#   'location': {'latitude': '40.604107',
#    'longitude': '-74.01824',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BAY 8 STREET',
#   'off_street_name': 'SHORE PARKWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724448',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Pick-up Truck'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '23:04',
#   'borough': 'BROOKLYN',
#   'zip_code': '11236',
#   'latitude': '40.648354',
#   'longitude': '-73.91001',
#   'location': {'latitude': '40.648354',
#    'longitude': '-73.91001',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 94 STREET',
#   'off_street_name': 'AVENUE D',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Traffic Control Disregarded',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724779',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Motorbike'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '8:35',
#   'latitude': '40.774677',
#   'longitude': '-73.98221',
#   'location': {'latitude': '40.774677',
#    'longitude': '-73.98221',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WEST 67 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Backing Unsafely',
#   'collision_id': '4724536',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Box Truck'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '12:30',
#   'borough': 'BROOKLYN',
#   'zip_code': '11238',
#   'latitude': '40.687756',
#   'longitude': '-73.96316',
#   'location': {'latitude': '40.687756',
#    'longitude': '-73.96316',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '44        CLIFTON PLACE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4725080',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '14:53',
#   'borough': 'MANHATTAN',
#   'zip_code': '10002',
#   'latitude': '40.71738',
#   'longitude': '-73.99131',
#   'location': {'latitude': '40.71738',
#    'longitude': '-73.99131',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'GRAND STREET',
#   'off_street_name': 'ALLEN STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Traffic Control Disregarded',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724636',
#   'vehicle_type_code1': 'Bus',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '9:53',
#   'borough': 'BRONX',
#   'zip_code': '10475',
#   'latitude': '40.890076',
#   'longitude': '-73.819855',
#   'location': {'latitude': '40.890076',
#    'longitude': '-73.819855',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BOSTON ROAD',
#   'off_street_name': 'ROPES AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unsafe Lane Changing',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'collision_id': '4724583',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Sedan',
#   'vehicle_type_code_3': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '13:15',
#   'latitude': '40.578823',
#   'longitude': '-73.98628',
#   'location': {'latitude': '40.578823',
#    'longitude': '-73.98628',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'NEPTUNE AVENUE',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '2',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'View Obstructed/Limited',
#   'contributing_factor_vehicle_2': 'Driver Inattention/Distraction',
#   'collision_id': '4724967',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '21:50',
#   'borough': 'BRONX',
#   'zip_code': '10472',
#   'latitude': '40.836708',
#   'longitude': '-73.87527',
#   'location': {'latitude': '40.836708',
#    'longitude': '-73.87527',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 177 STREET',
#   'off_street_name': 'BRONX RIVER AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unsafe Speed',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4725011',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '13:30',
#   'latitude': '40.698696',
#   'longitude': '-73.93477',
#   'location': {'latitude': '40.698696',
#    'longitude': '-73.93477',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BUSHWICK AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Backing Unsafely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4724607',
#   'vehicle_type_code1': 'PK',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2024-05-14T00:00:00.000',
#   'crash_time': '10:26',
#   'latitude': '40.68623',
#   'longitude': '-74.00046',
#   'location': {'latitude': '40.68623',
#    'longitude': '-74.00046',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BROOKLYN QUEENS EXPRESSWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'collision_id': '4724711',
#   'vehicle_type_code1': 'Pick-up Truck',
#   'vehicle_type_code2': 'Sedan',
#   'vehicle_type_code_3': 'Taxi'}]

# %% [markdown]
# ### TODO
#
# Set up integrations for these datasets. Run them daily. Write to cloud storage. Seems like they're up to date as of a few days ago (When I pulled around midnight on May 17, most recent data showed May 13). Partition by day.
#
# After tables are created, join them to create more exhaustive dataset. Motor vehicle collisions have lat/long data. Questions for EDA:
# - what does a map viz look like
# - is there a location where accidents happen more often
# - people stats? age/bodily injury/death
# - what type of vehicle?
# - are certain vehicles more prone to pedestrian death (trucks obvi).
#
# Put a streamlit dashboard together that shows the stuff you want to display.
#
# After all that, what is something we can predict? and how can we operationalize it? Apply some of the skills you learned in the MLOps class.

# %%
r3 = requests.get('https://data.cityofnewyork.us/resource/h9gi-nx95.json?crash_date=2023-11-22T00:00:00.000', auth=(api_key, secret_key))
print(r3.status_code)
print(len(r3.json()))
r3.json()
# Out:
# 200
# 295
# [{'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '4:52',
#   'borough': 'BRONX',
#   'zip_code': '10462',
#   'cross_street_name': '2149      GLEASON AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681370',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '13:25',
#   'latitude': '40.720005',
#   'longitude': '-73.78463',
#   'location': {'latitude': '40.720005',
#    'longitude': '-73.78463',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'GRAND CENTRAL PKWY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681714',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '17:27',
#   'borough': 'QUEENS',
#   'zip_code': '11377',
#   'latitude': '40.743454',
#   'longitude': '-73.91484',
#   'location': {'latitude': '40.743454',
#    'longitude': '-73.91484',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '50 STREET',
#   'off_street_name': 'ROOSEVELT AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681482',
#   'vehicle_type_code1': 'E-Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '12:10',
#   'cross_street_name': '100       WEST DRIVE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681543',
#   'vehicle_type_code1': 'GOLF CART'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '19:50',
#   'latitude': '40.62095',
#   'longitude': '-73.9555',
#   'location': {'latitude': '40.62095',
#    'longitude': '-73.9555',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'OCEAN AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'collision_id': '4682017',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '22:55',
#   'borough': 'QUEENS',
#   'zip_code': '11105',
#   'latitude': '40.775764',
#   'longitude': '-73.910164',
#   'location': {'latitude': '40.775764',
#    'longitude': '-73.910164',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '31-13     DITMARS BOULEVARD',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681827',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '7:41',
#   'latitude': '40.686226',
#   'longitude': '-73.9124',
#   'location': {'latitude': '40.686226',
#    'longitude': '-73.9124',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BUSHWICK AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682217',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'PK'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '17:00',
#   'borough': 'MANHATTAN',
#   'zip_code': '10011',
#   'latitude': '40.743507',
#   'longitude': '-74.0055',
#   'location': {'latitude': '40.743507',
#    'longitude': '-74.0055',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '419       WEST 17 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682069',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '3:15',
#   'borough': 'BROOKLYN',
#   'zip_code': '11209',
#   'latitude': '40.63286',
#   'longitude': '-74.02425',
#   'location': {'latitude': '40.63286',
#    'longitude': '-74.02425',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '72 STREET',
#   'off_street_name': '4 AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'collision_id': '4681127',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '8:50',
#   'latitude': '40.80545',
#   'longitude': '-73.965775',
#   'location': {'latitude': '40.80545',
#    'longitude': '-73.965775',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WEST 112 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Fell Asleep',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682120',
#   'vehicle_type_code1': 'Pick-up Truck',
#   'vehicle_type_code2': 'Taxi'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '0:00',
#   'borough': 'BROOKLYN',
#   'zip_code': '11249',
#   'latitude': '40.70724',
#   'longitude': '-73.96594',
#   'location': {'latitude': '40.70724',
#    'longitude': '-73.96594',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'DIVISION AVENUE',
#   'off_street_name': 'BERRY STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681832',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Box Truck'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '9:09',
#   'latitude': '40.778603',
#   'longitude': '-73.8443',
#   'location': {'latitude': '40.778603',
#    'longitude': '-73.8443',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '124 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682155',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '21:46',
#   'borough': 'BRONX',
#   'zip_code': '10465',
#   'latitude': '40.828835',
#   'longitude': '-73.82162',
#   'location': {'latitude': '40.828835',
#    'longitude': '-73.82162',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'LOGAN AVENUE',
#   'off_street_name': 'PHILIP AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Other Vehicular',
#   'contributing_factor_vehicle_2': 'Other Vehicular',
#   'collision_id': '4681687',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '1:16',
#   'latitude': '40.847412',
#   'longitude': '-73.93331',
#   'location': {'latitude': '40.847412',
#    'longitude': '-73.93331',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WEST 179 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Backing Unsafely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681196',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Tow Truck / Wrecker'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '19:30',
#   'borough': 'QUEENS',
#   'zip_code': '11432',
#   'latitude': '40.70853',
#   'longitude': '-73.79995',
#   'location': {'latitude': '40.70853',
#    'longitude': '-73.79995',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '162-23    HILLSIDE AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Driver Inattention/Distraction',
#   'collision_id': '4681566',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '8:57',
#   'borough': 'BROOKLYN',
#   'zip_code': '11207',
#   'latitude': '40.689365',
#   'longitude': '-73.9058',
#   'location': {'latitude': '40.689365',
#    'longitude': '-73.9058',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'COOPER STREET',
#   'off_street_name': 'WILSON AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682257',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Pick-up Truck'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '10:25',
#   'latitude': '40.597267',
#   'longitude': '-73.998665',
#   'location': {'latitude': '40.597267',
#    'longitude': '-73.998665',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BAY PARKWAY',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Driver Inattention/Distraction',
#   'collision_id': '4681263',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '19:32',
#   'on_street_name': 'ROCKAWAY FREEWAY',
#   'off_street_name': 'BEACH 49 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'collision_id': '4681871',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '15:55',
#   'borough': 'BROOKLYN',
#   'zip_code': '11236',
#   'latitude': '40.640175',
#   'longitude': '-73.917175',
#   'location': {'latitude': '40.640175',
#    'longitude': '-73.917175',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '550       EAST 81 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unsafe Speed',
#   'collision_id': '4681453'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '23:25',
#   'latitude': '40.843678',
#   'longitude': '-73.89426',
#   'location': {'latitude': '40.843678',
#    'longitude': '-73.89426',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'CROSS BRONX EXPY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Reaction to Uninvolved Vehicle',
#   'collision_id': '4681612',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '17:42',
#   'borough': 'MANHATTAN',
#   'zip_code': '10001',
#   'latitude': '0.0000000',
#   'longitude': '0.0000000',
#   'location': {'latitude': '0.0',
#    'longitude': '0.0',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '535       WEST 30 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Turning Improperly',
#   'collision_id': '4682042',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '23:58',
#   'borough': 'MANHATTAN',
#   'zip_code': '10035',
#   'latitude': '40.80016',
#   'longitude': '-73.93538',
#   'location': {'latitude': '40.80016',
#    'longitude': '-73.93538',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 121 STREET',
#   'off_street_name': '2 AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681623',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '13:00',
#   'borough': 'MANHATTAN',
#   'zip_code': '10002',
#   'latitude': '40.718452',
#   'longitude': '-73.99008',
#   'location': {'latitude': '40.718452',
#    'longitude': '-73.99008',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '97        ORCHARD STREET',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '2',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Alcohol Involvement',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'collision_id': '4681424',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Pick-up Truck',
#   'vehicle_type_code_3': 'Pick-up Truck'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '13:01',
#   'borough': 'BROOKLYN',
#   'zip_code': '11215',
#   'latitude': '40.675076',
#   'longitude': '-73.98801',
#   'location': {'latitude': '40.675076',
#    'longitude': '-73.98801',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '3 AVENUE',
#   'off_street_name': '3 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Other Vehicular',
#   'contributing_factor_vehicle_2': 'Following Too Closely',
#   'collision_id': '4682431',
#   'vehicle_type_code1': 'Pick-up Truck',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '12:40',
#   'borough': 'BROOKLYN',
#   'zip_code': '11208',
#   'latitude': '40.669456',
#   'longitude': '-73.865654',
#   'location': {'latitude': '40.669456',
#    'longitude': '-73.865654',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '799       LINCOLN AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682133',
#   'vehicle_type_code1': 'Tanker',
#   'vehicle_type_code2': 'Lift Boom'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '6:37',
#   'borough': 'BRONX',
#   'zip_code': '10472',
#   'latitude': '40.831676',
#   'longitude': '-73.87587',
#   'location': {'latitude': '40.831676',
#    'longitude': '-73.87587',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '1603      EAST 172 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681371',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '16:46',
#   'latitude': '40.69733',
#   'longitude': '-73.78456',
#   'location': {'latitude': '40.69733',
#    'longitude': '-73.78456',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '109 AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681449',
#   'vehicle_type_code1': 'Chassis Cab',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '0:00',
#   'latitude': '40.835484',
#   'longitude': '-73.9494',
#   'location': {'latitude': '40.835484',
#    'longitude': '-73.9494',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'HENRY HUDSON PARKWAY',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pavement Defective',
#   'collision_id': '4681286',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '22:53',
#   'borough': 'BRONX',
#   'zip_code': '10453',
#   'latitude': '40.848637',
#   'longitude': '-73.91169',
#   'location': {'latitude': '40.848637',
#    'longitude': '-73.91169',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'JEROME AVENUE',
#   'off_street_name': 'EAST 176 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681555',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '9:46',
#   'latitude': '40.708004',
#   'longitude': '-73.84458',
#   'location': {'latitude': '40.708004',
#    'longitude': '-73.84458',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'JACKIE ROBINSON PKWY',
#   'number_of_persons_injured': '4',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '4',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unsafe Lane Changing',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'contributing_factor_vehicle_4': 'Unspecified',
#   'collision_id': '4681407',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code_3': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code_4': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '11:29',
#   'borough': 'BRONX',
#   'zip_code': '10454',
#   'latitude': '40.814186',
#   'longitude': '-73.92125',
#   'location': {'latitude': '40.814186',
#    'longitude': '-73.92125',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '3 AVENUE',
#   'off_street_name': 'EAST 145 STREET',
#   'number_of_persons_injured': '3',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '3',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681666',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '1:30',
#   'latitude': '40.80119',
#   'longitude': '-73.93003',
#   'location': {'latitude': '40.80119',
#    'longitude': '-73.93003',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'FDR DRIVE',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '2',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'collision_id': '4681627',
#   'vehicle_type_code1': 'Taxi'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '10:00',
#   'latitude': '40.727585',
#   'longitude': '-73.88781',
#   'location': {'latitude': '40.727585',
#    'longitude': '-73.88781',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'LONG ISLAND EXPRESSWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682500',
#   'vehicle_type_code1': 'Pick-up Truck',
#   'vehicle_type_code2': 'Pick-up Truck'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '5:10',
#   'on_street_name': 'MAJOR DEEGAN EXPRESSWAY RAMP',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pavement Slippery',
#   'collision_id': '4681321',
#   'vehicle_type_code1': 'Tanker'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '15:49',
#   'latitude': '40.64703',
#   'longitude': '-74.012',
#   'location': {'latitude': '40.64703',
#    'longitude': '-74.012',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '4 AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'contributing_factor_vehicle_2': 'Driver Inattention/Distraction',
#   'collision_id': '4681432',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '6:04',
#   'latitude': '40.826275',
#   'longitude': '-73.85971',
#   'location': {'latitude': '40.826275',
#    'longitude': '-73.85971',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BRUCKNER BOULEVARD',
#   'off_street_name': 'WHITE PLAINS ROAD',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'View Obstructed/Limited',
#   'collision_id': '4682417',
#   'vehicle_type_code1': 'Bus'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '7:30',
#   'latitude': '40.59907',
#   'longitude': '-73.90498',
#   'location': {'latitude': '40.59907',
#    'longitude': '-73.90498',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BELT PARKWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pavement Slippery',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681759',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '18:11',
#   'borough': 'BROOKLYN',
#   'zip_code': '11236',
#   'latitude': '40.64831',
#   'longitude': '-73.89748',
#   'location': {'latitude': '40.64831',
#    'longitude': '-73.89748',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '10311     GLENWOOD ROAD',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681454',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '14:00',
#   'latitude': '40.804417',
#   'longitude': '-73.955376',
#   'location': {'latitude': '40.804417',
#    'longitude': '-73.955376',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WEST 116 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#   'collision_id': '4681388',
#   'vehicle_type_code1': 'Motorcycle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '12:34',
#   'borough': 'MANHATTAN',
#   'zip_code': '10029',
#   'latitude': '40.78882',
#   'longitude': '-73.943756',
#   'location': {'latitude': '40.78882',
#    'longitude': '-73.943756',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '2002      2 AVENUE',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '2',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681798',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '9:10',
#   'borough': 'BROOKLYN',
#   'zip_code': '11203',
#   'latitude': '40.64588',
#   'longitude': '-73.945175',
#   'location': {'latitude': '40.64588',
#    'longitude': '-73.945175',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '450       EAST 34 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4682026',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '17:10',
#   'borough': 'QUEENS',
#   'zip_code': '11432',
#   'latitude': '40.714333',
#   'longitude': '-73.77686',
#   'location': {'latitude': '40.714333',
#    'longitude': '-73.77686',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '185-05    HILLSIDE AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681550',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '23:48',
#   'latitude': '40.639996',
#   'longitude': '-74.02442',
#   'location': {'latitude': '40.639996',
#    'longitude': '-74.02442',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BELT PARKWAY',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passenger Distraction',
#   'contributing_factor_vehicle_2': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_3': 'Passenger Distraction',
#   'collision_id': '4681515',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan',
#   'vehicle_type_code_3': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '19:05',
#   'latitude': '40.636326',
#   'longitude': '-73.958405',
#   'location': {'latitude': '40.636326',
#    'longitude': '-73.958405',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'OCEAN AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682018',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '20:30',
#   'borough': 'BROOKLYN',
#   'zip_code': '11236',
#   'latitude': '40.6411',
#   'longitude': '-73.90463',
#   'location': {'latitude': '40.6411',
#    'longitude': '-73.90463',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'FLATLANDS AVENUE',
#   'off_street_name': 'EAST 92 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Other Vehicular',
#   'collision_id': '4682413',
#   'vehicle_type_code1': 'E-Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '23:30',
#   'latitude': '40.843678',
#   'longitude': '-73.89426',
#   'location': {'latitude': '40.843678',
#    'longitude': '-73.89426',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'CROSS BRONX EXPY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681617',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '12:45',
#   'borough': 'BROOKLYN',
#   'zip_code': '11230',
#   'latitude': '40.62813',
#   'longitude': '-73.96583',
#   'location': {'latitude': '40.62813',
#    'longitude': '-73.96583',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '1204      CONEY ISLAND AVENUE',
#   'number_of_persons_injured': '3',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '3',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Brakes Defective',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681461',
#   'vehicle_type_code1': 'Bus',
#   'vehicle_type_code2': 'Bus'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '13:30',
#   'latitude': '40.57397',
#   'longitude': '-74.16992',
#   'location': {'latitude': '40.57397',
#    'longitude': '-74.16992',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'RICHMOND AVENUE',
#   'number_of_persons_injured': '5',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '5',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Reaction to Uninvolved Vehicle',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'contributing_factor_vehicle_4': 'Unspecified',
#   'collision_id': '4681763',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code_3': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code_4': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '9:00',
#   'borough': 'STATEN ISLAND',
#   'zip_code': '10306',
#   'latitude': '40.568104',
#   'longitude': '-74.11515',
#   'location': {'latitude': '40.568104',
#    'longitude': '-74.11515',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'CLAWSON STREET',
#   'off_street_name': 'LINDBERGH AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'collision_id': '4681528',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '22:05',
#   'borough': 'MANHATTAN',
#   'zip_code': '10024',
#   'latitude': '40.783897',
#   'longitude': '-73.97407',
#   'location': {'latitude': '40.783897',
#    'longitude': '-73.97407',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WEST 82 STREET',
#   'off_street_name': 'COLUMBUS AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681562',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '10:30',
#   'latitude': '40.72656',
#   'longitude': '-73.83802',
#   'location': {'latitude': '40.72656',
#    'longitude': '-73.83802',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'GRAND CENTRAL PKWY',
#   'number_of_persons_injured': '3',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '3',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681713',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '0:00',
#   'borough': 'MANHATTAN',
#   'zip_code': '10027',
#   'latitude': '40.81636',
#   'longitude': '-73.954094',
#   'location': {'latitude': '40.81636',
#    'longitude': '-73.954094',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'AMSTERDAM AVENUE',
#   'off_street_name': 'WEST 131 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pavement Slippery',
#   'collision_id': '4681128',
#   'vehicle_type_code1': 'Moped'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '13:55',
#   'borough': 'BROOKLYN',
#   'zip_code': '11226',
#   'latitude': '40.650387',
#   'longitude': '-73.95872',
#   'location': {'latitude': '40.650387',
#    'longitude': '-73.95872',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'FLATBUSH AVENUE',
#   'off_street_name': 'CHURCH AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Passing Too Closely',
#   'collision_id': '4682052',
#   'vehicle_type_code1': 'Bus',
#   'vehicle_type_code2': 'E-Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '18:49',
#   'borough': 'MANHATTAN',
#   'zip_code': '10010',
#   'latitude': '40.74147',
#   'longitude': '-73.985435',
#   'location': {'latitude': '40.74147',
#    'longitude': '-73.985435',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 25 STREET',
#   'off_street_name': 'PARK AVENUE SOUTH',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Turning Improperly',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681494',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Taxi'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '4:20',
#   'borough': 'QUEENS',
#   'zip_code': '11385',
#   'latitude': '40.702595',
#   'longitude': '-73.8553',
#   'location': {'latitude': '40.702595',
#    'longitude': '-73.8553',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WOODHAVEN BOULEVARD',
#   'off_street_name': 'MYRTLE AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing or Lane Usage Improper',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681201',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '23:00',
#   'borough': 'BRONX',
#   'zip_code': '10470',
#   'latitude': '40.90103',
#   'longitude': '-73.867485',
#   'location': {'latitude': '40.90103',
#    'longitude': '-73.867485',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '301       EAST 240 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681718',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '15:00',
#   'borough': 'BROOKLYN',
#   'zip_code': '11220',
#   'latitude': '40.638103',
#   'longitude': '-74.00326',
#   'location': {'latitude': '40.638103',
#    'longitude': '-74.00326',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '9 AVENUE',
#   'off_street_name': '53 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681460',
#   'vehicle_type_code1': 'Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '16:30',
#   'borough': 'QUEENS',
#   'zip_code': '11435',
#   'latitude': '40.712517',
#   'longitude': '-73.812454',
#   'location': {'latitude': '40.712517',
#    'longitude': '-73.812454',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '84-42     SMEDLEY STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'collision_id': '4681740',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '21:30',
#   'latitude': '40.734314',
#   'longitude': '-73.93803',
#   'location': {'latitude': '40.734314',
#    'longitude': '-73.93803',
# ...
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pavement Slippery',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'collision_id': '4683850',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan',
#   'vehicle_type_code_3': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '13:45',
#   'borough': 'MANHATTAN',
#   'zip_code': '10029',
#   'latitude': '40.79167',
#   'longitude': '-73.95093',
#   'location': {'latitude': '40.79167',
#    'longitude': '-73.95093',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 103 STREET',
#   'off_street_name': 'MADISON AVENUE',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing or Lane Usage Improper',
#   'contributing_factor_vehicle_2': 'Backing Unsafely',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'collision_id': '4683603',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan',
#   'vehicle_type_code_3': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '17:00',
#   'latitude': '40.707977',
#   'longitude': '-74.00801',
#   'location': {'latitude': '40.707977',
#    'longitude': '-74.00801',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WILLIAM STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4683902',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '7:00',
#   'borough': 'BROOKLYN',
#   'zip_code': '11201',
#   'latitude': '40.703014',
#   'longitude': '-73.98406',
#   'location': {'latitude': '40.703014',
#    'longitude': '-73.98406',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '247       WATER STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4684069',
#   'vehicle_type_code1': 'Ambulance',
#   'vehicle_type_code2': 'Van'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '8:00',
#   'borough': 'BRONX',
#   'zip_code': '10451',
#   'latitude': '40.81572',
#   'longitude': '-73.925064',
#   'location': {'latitude': '40.81572',
#    'longitude': '-73.925064',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 144 STREET',
#   'off_street_name': 'RIDER AVENUE',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '1',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4685379',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Bike'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '12:05',
#   'borough': 'BROOKLYN',
#   'zip_code': '11236',
#   'latitude': '40.645546',
#   'longitude': '-73.90566',
#   'location': {'latitude': '40.645546',
#    'longitude': '-73.90566',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 95 STREET',
#   'off_street_name': 'FARRAGUT ROAD',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4685221',
#   'vehicle_type_code1': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '0:09',
#   'borough': 'MANHATTAN',
#   'zip_code': '10017',
#   'latitude': '40.75457',
#   'longitude': '-73.97169',
#   'location': {'latitude': '40.75457',
#    'longitude': '-73.97169',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '3 AVENUE',
#   'off_street_name': 'EAST 48 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4685357',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '12:15',
#   'latitude': '40.759617',
#   'longitude': '-73.961975',
#   'location': {'latitude': '40.759617',
#    'longitude': '-73.961975',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 59 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inexperience',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4685491',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '15:30',
#   'latitude': '40.877106',
#   'longitude': '-73.90616',
#   'location': {'latitude': '40.877106',
#    'longitude': '-73.90616',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'BROADWAY',
#   'off_street_name': 'WEST 230 STREET',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Failure to Yield Right-of-Way',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4685990',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '23:15',
#   'borough': 'MANHATTAN',
#   'zip_code': '10031',
#   'latitude': '40.82269',
#   'longitude': '-73.94947',
#   'location': {'latitude': '40.82269',
#    'longitude': '-73.94947',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'AMSTERDAM AVENUE',
#   'off_street_name': 'WEST 141 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Passing or Lane Usage Improper',
#   'collision_id': '4685989',
#   'vehicle_type_code1': 'Motorcycle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '6:49',
#   'borough': 'BRONX',
#   'zip_code': '10468',
#   'latitude': '40.87023',
#   'longitude': '-73.90061',
#   'location': {'latitude': '40.87023',
#    'longitude': '-73.90061',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'CLAFLIN AVENUE',
#   'off_street_name': 'WEST 195 STREET',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'collision_id': '4686299',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '16:20',
#   'borough': 'BROOKLYN',
#   'zip_code': '11226',
#   'latitude': '40.64832',
#   'longitude': '-73.96069',
#   'location': {'latitude': '40.64832',
#    'longitude': '-73.96069',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'cross_street_name': '590       OCEAN AVENUE',
#   'number_of_persons_injured': '3',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '3',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682054',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '9:36',
#   'on_street_name': 'MAJOR DEEGAN EXPRESSWAY RAMP',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Alcohol Involvement',
#   'contributing_factor_vehicle_2': 'Passing or Lane Usage Improper',
#   'collision_id': '4686918',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '6:40',
#   'latitude': '40.843994',
#   'longitude': '-73.89752',
#   'location': {'latitude': '40.843994',
#    'longitude': '-73.89752',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': '3 AVENUE',
#   'off_street_name': 'CROSS BRONX EXPRESSWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'contributing_factor_vehicle_3': 'Unspecified',
#   'contributing_factor_vehicle_4': 'Unspecified',
#   'collision_id': '4689245',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Sedan',
#   'vehicle_type_code_3': 'Sedan',
#   'vehicle_type_code_4': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '2:35',
#   'borough': 'BROOKLYN',
#   'zip_code': '11236',
#   'latitude': '40.652805',
#   'longitude': '-73.90935',
#   'location': {'latitude': '40.652805',
#    'longitude': '-73.90935',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 98 STREET',
#   'off_street_name': 'BOYLAND STREET',
#   'number_of_persons_injured': '2',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '2',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4689505',
#   'vehicle_type_code1': 'Sedan',
#   'vehicle_type_code2': 'Sedan'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '2:55',
#   'borough': 'BRONX',
#   'zip_code': '10471',
#   'latitude': '40.90104',
#   'longitude': '-73.89689',
#   'location': {'latitude': '40.90104',
#    'longitude': '-73.89689',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'WEST 254 STREET',
#   'off_street_name': 'BROADWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Pavement Slippery',
#   'collision_id': '4692331',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '8:50',
#   'borough': 'BRONX',
#   'zip_code': '10467',
#   'latitude': '40.879578',
#   'longitude': '-73.879',
#   'location': {'latitude': '40.879578',
#    'longitude': '-73.879',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'EAST 210 STREET',
#   'off_street_name': 'BAINBRIDGE AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '1',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Driver Inattention/Distraction',
#   'collision_id': '4692527'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '8:25',
#   'on_street_name': 'MAJOR DEEGAN EXPRESSWAY RAMP',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4682703',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'},
#  {'crash_date': '2023-11-22T00:00:00.000',
#   'crash_time': '10:55',
#   'borough': 'BROOKLYN',
#   'zip_code': '11238',
#   'latitude': '40.681564',
#   'longitude': '-73.96658',
#   'location': {'latitude': '40.681564',
#    'longitude': '-73.96658',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   'on_street_name': 'ATLANTIC AVENUE',
#   'off_street_name': 'CLINTON AVENUE',
#   'number_of_persons_injured': '1',
#   'number_of_persons_killed': '1',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '1',
#   'number_of_motorist_killed': '1',
#   'contributing_factor_vehicle_1': 'Following Too Closely',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4681770',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Tractor Truck Diesel'}]

# %%
# download data. arg inputs?
dt = (date.today() - timedelta(days=5)).strftime('%Y-%m-%d')

endpoints = {
    "pedestrian": "f55k-p6yu.json",
    "collision": "h9gi-nx95.json"
}
# Out:
# '2024-05-14'

# %%
def download_data(dt, endpoint):
    base_url = "https://data.cityofnewyork.us/resource/"
    endpoints = {
        "pedestrian": "f55k-p6yu.json",
        "collision": "h9gi-nx95.json"
    }
    ep = endpoints[endpoint]
    params = f"?crash_date={dt}T00:00:00.000"
    url = base_url + ep + params
    response = requests.get(url, auth=(api_key, secret_key))
    response.raise_for_status()
    return response.json()

c = download_data('2024-01-01', 'collision')
print(len(c))
c[:1]
# Out:
# 246
# [{'crash_date': '2024-01-01T00:00:00.000',
#   'crash_time': '18:34',
#   'on_street_name': 'CHURCH AVENUE',
#   'off_street_name': 'OCEAN PARKWAY',
#   'number_of_persons_injured': '0',
#   'number_of_persons_killed': '0',
#   'number_of_pedestrians_injured': '0',
#   'number_of_pedestrians_killed': '0',
#   'number_of_cyclist_injured': '0',
#   'number_of_cyclist_killed': '0',
#   'number_of_motorist_injured': '0',
#   'number_of_motorist_killed': '0',
#   'contributing_factor_vehicle_1': 'Unspecified',
#   'contributing_factor_vehicle_2': 'Unspecified',
#   'collision_id': '4691979',
#   'vehicle_type_code1': 'Station Wagon/Sport Utility Vehicle',
#   'vehicle_type_code2': 'Station Wagon/Sport Utility Vehicle'}]

# %%
def create_tmp_dir(dt, data):
    "Create a tmp directory after downloading data"
    data_dir = os.path.join('..', 'data', 'tmp', dt)
    
    # create dir if it doesn't exist
    os.makedirs(data_dir, exist_ok=True)
    
    # write the data to a json file
    file_path = os.path.join(data_dir, 'data.json')
    with open(file_path, 'w') as out:
        for record in data:
            json.dump(record, out)
            out.write('\n')
    print(f"data saved to {file_path}")
# Out:
# data saved to ../data/tmp/2024-01-01/data.json

# %%
def sync_to_gcs(dt, tmp_dir):
    source_file = tmp_dir # "../data/tmp/2024-01-01/data.json"
    destination_blob_name = f"motor-vehicle-crashes/collisions/{dt}/data.json"
    storage_client = storage.Client()
    bucket = storage_client.bucket('machine-learning-workspace')
    blob = bucket.blob(destination_blob_name)
    blob.upload_from_filename(source_file)
    print(f"File {source_file} uploaded to {destination_blob_name}.")
# Out:
# File ../data/tmp/2024-01-01/data.json uploaded to motor-vehicle-crashes/collisions/2024-01-01/data.json.

# %%
# delete local file.
if os.path.isfile(file_path):
    os.remove(file_path)
    print(f"File {file_path} deleted.")
else:
    print(f"File {file_path} not found.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[73], line 3
#       1 # delete local file
#       2 if os.path.isfile(file_path):
# ----> 3     os.rmdir(data_dir)
#       4     print(f"Directory {file_path} deleted.")
#       5 else:
#
# OSError: [Errno 66] Directory not empty: '../data/tmp/2024-01-01'

# %%
def remove_local_dir(tmp_dir):
    if path.exists(tmp_dir):
        shutil.rmtree(tmp_dir)
# Out:
# '../data/tmp/2024-01-01'

# %% [markdown]
# ### TODO 2024-05-20
# - Refactor
# - Recreate cloud composer environment now that you've updated permissions.
# - Cloud Composer discovery.
